# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
z=[1,2,3]
exp=np.exp(z)
num=np.sum(exp)
sigma=exp/num
print(sigma)
print(np.sum(sigma))
# Out:
# [0.09003057 0.24472847 0.66524096]
# 1.0

# %%
# Manual method

z=np.random.randint(-5,high=15,size=25)
sigma=np.exp(z)/np.sum(np.exp(z))

plt.plot(z,sigma,'ko')
plt.xlabel('Original number (z)')
plt.ylabel('Softmax $\sigma$')
plt.title('$\sum\sigma$=%g' %np.sum(sigma))
plt.show()

# %% [markdown]
# ## Using Pytorch

# %%
softfun=nn.Softmax(dim=0)
sigmaT=softfun(torch.Tensor(z))
print(sigmaT)
# Out:
# tensor([1.2997e-01, 1.1852e-04, 3.2217e-04, 8.7574e-04, 1.1852e-04, 1.7590e-02,
#         5.3807e-09, 1.2997e-01, 6.4709e-03, 1.1852e-04, 4.3600e-05, 2.9378e-07,
#         3.9758e-08, 2.9378e-07, 8.7574e-04, 3.5330e-01, 1.9795e-09, 1.6040e-05,
#         3.5330e-01, 2.1707e-06, 3.9758e-08, 1.9795e-09, 3.2217e-04, 6.4709e-03,
#         1.1852e-04])

# %%
plt.plot(sigma,sigmaT,'ko')
plt.xlabel('"Manual" Softmax')
plt.ylabel('Pytorch nn.softmax')
plt.title(f'The two methods correlate at r={np.corrcoef(sigma,sigmaT)[0,1]}')
plt.show()
